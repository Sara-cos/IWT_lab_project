# %%
from py_backend.logger.log_db import Logger
from py_backend.mongo_db.crud import Operations

# %%
logger = Logger()
mongo_db = Operations("ExamPortal", logger)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1c1d86403be9> in <module>
#       1 logger = Logger()
# ----> 2 config.mongo_db = Operations("ExamPortal", logger)
#
# ~\PycharmProjects\IWT_lab_project\py_backend\mongo_db\crud.py in __init__(self, db_name, logger)
#      24             self.my_db = self.client[db_name]
#      25             self.result = "connection with database successful"
# ---> 26             self.lg.log("info", self.result)
#      27         except Exception as e:
#      28             self.result = str(e)
#
# ~\PycharmProjects\IWT_lab_project\py_backend\logger\log_db.py in log(self, levelname, message)
#      33         levelname = levelname.upper()
#      34         if levelname == "INFO":
# ---> 35             self.db_logger.info(str(message))
#      36         elif levelname == "DEBUG":
# ...
